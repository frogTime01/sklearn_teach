# %% [markdown]
# ## Learning with a teacher

# %% [markdown]
# ### `1 task`

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# "Boston House Prices dataset" пишет, что больше не доступен с версии 1.2

# %%
X = pd.read_csv("boston.csv")
y = X["medv"]
X = X.drop(["medv"], axis=1)
X.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
X_test.shape
# Out:
# (152, 13)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
check_test = pd.DataFrame({"y_test": y_test, "y_pred": y_pred})
check_test.head()
# Out:
#      y_test     y_pred
# 173    23.6  28.648960
# 274    32.4  36.495014
# 491    13.6  15.411193
# 72     22.8  25.403213
# 452    16.1  18.855280

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(check_test['y_pred'], check_test["y_test"])
# Out:
# 21.517444231177432

# %% [markdown]
# ## `2 task`

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=1000, max_depth=12, random_state=42)
model.fit(X_train, y_train.values[:])
y_pred_thx_tree = model.predict(X_test)
check_test_thx_tree = pd.DataFrame({"y_test": y_test, "y_pred": y_pred_thx_tree})
check_test_thx_tree.head()
# Out:
#      y_test     y_pred
# 173    23.6  22.806412
# 274    32.4  31.131464
# 491    13.6  16.339125
# 72     22.8  23.810726
# 452    16.1  17.139521

# %%
from sklearn.metrics import r2_score

r2_tree = r2_score(check_test_thx_tree["y_test"], check_test_thx_tree["y_pred"])
r2_lr = r2_score(check_test["y_test"], check_test["y_pred"])
print(f"r2_tree = {r2_tree}, r2_lr = {r2_lr}")

# Так как наилучший результат достигается при R2 = 1, то RandomForestRegressor показывает себя лучше чем LinearRegression.
# Out:
# r2_tree = 0.87472606157312, r2_lr = 0.7112260057484903

# %% [markdown]
# ### `3 task`

# %%
# ?RandomForestRegressor

# %%
feature_importances = model.feature_importances_
sum_feature_importances = feature_importances.sum()
sum_feature_importances
# Out:
# 1.0

# %%
df_feature = pd.DataFrame({"key_name": X.keys(), "feature_importances": feature_importances})
df_feature
# Out:
#    key_name  feature_importances
# 0      crim             0.031676
# 1        zn             0.001543
# 2     indus             0.007138
# 3      chas             0.001236
# 4       nox             0.014269
# 5        rm             0.402682
# 6       age             0.014299
# 7       dis             0.063973
# 8       rad             0.005281
# 9       tax             0.011525
# 10  ptratio             0.018081
# 11        b             0.012451
# 12    lstat             0.415847

# %%
df_feature.sort_values(by="feature_importances", ascending=False).head(2)
# Out:
#    key_name  feature_importances
# 12    lstat             0.415847
# 5        rm             0.402682

# %% [markdown]
# ### `4 task`

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("creditcard.csv")
df["Class"].value_counts(normalize=True)
# Out:
# 0    0.998273
# 1    0.001727
# Name: Class, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
pd.options.display.max_columns=100

# %%
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9       V10       V11       V12       V13       V14  \
# ...

# %%
X = df.drop(["Class"], axis=1)
y = df["Class"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100, stratify=y)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
print(y_train.value_counts())
print(y_test.value_counts())
# Out:
# (199364, 30) (85443, 30) (199364,) (85443,)
# 0    199020
# 1       344
# Name: Class, dtype: int64
# 0    85295
# 1      148
# Name: Class, dtype: int64

# %%
parameters = {"n_estimators": [10, 15], "max_features": np.arange(4, 7)}
clf = GridSearchCV(estimator=RandomForestClassifier(random_state=100), 
                   param_grid=parameters,
                   scoring="roc_auc", cv=3)

# %%
clf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=100),
#              param_grid={'max_features': array([4, 5, 6]),
#                          'n_estimators': [10, 15]},
#              scoring='roc_auc')

# %%
clf.best_params_
# Out:
# {'max_features': 5, 'n_estimators': 10}

# %%
y_pred_proba = clf.predict_proba(X_test)
y_pred_proba = y_pred_proba[:, 1]
y_pred_proba
# Out:
# array([0. , 0. , 0. , ..., 0. , 0. , 0.1])

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test, y_pred_proba)
# Out:
# 0.9253220539843436

# %% [markdown]
# ## Additional tasks

# %% [markdown]
# ### `1 task`

# %%
from sklearn.datasets import load_wine
data = load_wine()

# %% [markdown]
# ### `2 task`

# %%
data_keys = data.keys()
data_keys
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names'])

# %% [markdown]
# ### `3 task`

# %%
data.data
# Out:
# array([[1.423e+01, 1.710e+00, 2.430e+00, ..., 1.040e+00, 3.920e+00,
#         1.065e+03],
#        [1.320e+01, 1.780e+00, 2.140e+00, ..., 1.050e+00, 3.400e+00,
#         1.050e+03],
#        [1.316e+01, 2.360e+00, 2.670e+00, ..., 1.030e+00, 3.170e+00,
#         1.185e+03],
#        ...,
#        [1.327e+01, 4.280e+00, 2.260e+00, ..., 5.900e-01, 1.560e+00,
#         8.350e+02],
#        [1.317e+01, 2.590e+00, 2.370e+00, ..., 6.000e-01, 1.620e+00,
#         8.400e+02],
#        [1.413e+01, 4.100e+00, 2.740e+00, ..., 6.100e-01, 1.600e+00,
#         5.600e+02]])

# %%
print(data.DESCR)
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 178
#     :Number of Attributes: 13 numeric, predictive attributes and the class
#     :Attribute Information:
#  		- Alcohol
#  		- Malic acid
#  		- Ash
# 		- Alcalinity of ash
#  		- Magnesium
# 		- Total phenols
#  		- Flavanoids
#  		- Nonflavanoid phenols
#  		- Proanthocyanins
# 		- Color intensity
#  		- Hue
#  		- OD280/OD315 of diluted wines
#  		- Proline
#
#     - class:
#             - class_0
#             - class_1
#             - class_2
#
#     :Summary Statistics:
#
#     ============================= ==== ===== ======= =====
#                                    Min   Max   Mean     SD
#     ============================= ==== ===== ======= =====
#     Alcohol:                      11.0  14.8    13.0   0.8
#     Malic Acid:                   0.74  5.80    2.34  1.12
#     Ash:                          1.36  3.23    2.36  0.27
# ...

# %%
data.feature_names
# Out:
# ['alcohol',
#  'malic_acid',
#  'ash',
#  'alcalinity_of_ash',
#  'magnesium',
#  'total_phenols',
#  'flavanoids',
#  'nonflavanoid_phenols',
#  'proanthocyanins',
#  'color_intensity',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']

# %% [markdown]
# ### `4 task`

# %%
data.target_names
# Out:
# array(['class_0', 'class_1', 'class_2'], dtype='<U7')

# %%
data.target_names.size
# Out:
# 3

# %%
np.unique(data.target)
# Out:
# array([0, 1, 2])

# %% [markdown]
# ### `5 task`

# %%
X = pd.DataFrame(data.data, columns=data.feature_names)
X
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %% [markdown]
# ### `6 task`

# %%
X.shape
# Out:
# (178, 13)

# %%
X.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ### `7 task`

# %%
X['target'] = data.target
X["target"].astype(np.int64)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 173    2
# 174    2
# 175    2
# 176    2
# 177    2
# Name: target, Length: 178, dtype: int64

# %% [markdown]
# ### `8 task`

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
X_corr = X.corr()
X_corr = np.round(X_corr, 2)
X_corr[np.abs(X_corr) < 0.3] = 0

plt.figure(figsize = (15, 10))
sns.set(font_scale=1.4)
sns.heatmap(X_corr, annot=True, linewidths=.5, cmap="coolwarm")
plt.title("Corr matrix")
plt.show()

# %% [markdown]
# ### `9 task`

# %%
high_corr = X_corr.loc[(X_corr["target"].abs() > 0.5) & (X_corr["target"].index !="target"), "target"]
high_corr
# Out:
# alcalinity_of_ash               0.52
# total_phenols                  -0.72
# flavanoids                     -0.85
# hue                            -0.62
# od280/od315_of_diluted_wines   -0.79
# proline                        -0.63
# Name: target, dtype: float64

# %%
X.drop(["target"], axis=1, inplace=True)
X
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %% [markdown]
# ### `10 task`

# %%
for feature in high_corr.index:
    X[f"{feature}_2"] = X[feature] ** 2 
X
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
X.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...
